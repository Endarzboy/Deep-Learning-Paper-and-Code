# %% [markdown]
# > ### EEE4423: Signal Processing Lab
#
# # LAB #7: High-level Vision - Single Shot Object Detection (YOLO)

# %% [markdown]
# <div style="text-align: right"> Please upload your file @ yscec in the form of [ID_Name_YOLOLab7.ipynb]. </div></h4>

# %% [markdown]
# ### *Instructions:*
# - Write a program implementing a particular algorithm to solve a given problem.
# - <span style="color:red">**Report and discuss your results. Analyze the algorithm, theoretically and empirically.**</span>
# - Each team must write their own answers and codes (<span style="color:red">**if not you will get a F grade**</span>).

# %% [markdown]
# <h2><span style="color:blue">2014142243 차현수</span> </h2>

# %%
import datetime
print("This code is written at " + str(datetime.datetime.now()))
# Out:
# This code is written at 2021-04-28 03:37:26.093910

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torch.utils.data as data
from torch.autograd import Variable

import torchvision.datasets as dsets

import numpy as np
import cv2

import os
import struct
import copy
import random

import time
import datetime

import math

from PIL import Image
import torchvision.transforms as transforms
from torchvision.transforms import Compose, ToTensor, Resize
from torch.utils import data
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1. What is the Object Detection?
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1pOo5As8Qo8bQOQjOkkpRwjVKcKNB4gSE" alt="no_image" style="width: 800px;"/>
# >
# > - The difference between $\bf{classification}$ (left) and $\bf{detection}$ (right) is simple
# >
# > - In image classification, the entire image is classified with a single label
# >
# > - In object detection, the network localizes (potentially multiple) objects within the image
# >
# > - Therefore, given the image, the obejct detection networks ouput a list of bounding box, class label, and **probability/confidence score**
# >
#
# ### 2. About YOLO (Main idea)
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1K7tvcGXdRHBc_t5p-m3uyRrCBFbJ9ze5" alt="no_image" style="width: 800px;"/>
# >
# > - YOLO is an algorithm for object detection
# >
# > - They reframe object detection as a $\bf{single\ regression\ problem}$, straight from image pixels to bounding box coordinates and class probabilities
# >
# > - Using YOLO, you only look once (YOLO) at an image to predict what objects are present and where they are
# >
# > - The advantage of YOLO is the speed, which is extremely fast, since the authors reframe detection as a regression problem not using a complex pipeline
# >
# > - What are differences between YOLO and previous detectors?? Refer to https://towardsdatascience.com/r-cnn-fast-r-cnn-faster-r-cnn-yolo-object-detection-algorithms-36d53571365e

# %% [markdown]
# ### 3. Building a YOLO with PyTorch
#
# > ### YOLO model:
# > - 22Convolutional Layers
# >
# >     - Note that, first and 20th conv layers have stride 2 for halving output size
# >
# > - 4 Max Pooling Layers
# >
# > - 2 Fully Connected Layers
# >
# > - Leaky ReLu Activation for all layers except for the last layer
#
# ### 4. Implementing YOLO
# >
# > - The input image is divided into an S $\times$ S grid of cells
# >
# > - Each grid cell predicts B (=2) bounding boxes as well as C (=20) class probabilities
# >
# > - Each bounding box consists of 5 predictions: x, y, w, h, and confidence
# >
# > - The (x,y) coordinates represent the center of the box relative to the bounds of the grid cell
# >
# > - The width and height are predicted relative to the whole image
# >
# > - If no object exists in that cell, the confidence score is zero.
# >
# > - If the cell contains objects, the confidence score is equal to the intersection over union (IOU) between the predicted box and the ground truth (**This is important for building the loss function**)
# >
# > - Thus, the output vector is a S $\times$ S $\times$ (B $\times$ 5 + C) (= 7 $\times$ 7 $\times$ 30)
# >
# > <img src="https://drive.google.com/uc?export=view&id=1LdKtTyYjGKKWmu-4nTYBEMI7n4Sk0aeB" alt="no_image" style="width: 600px;"/>
# >
# > - You must study *generate_target* function in detail, it contains the process of generating output vectors
# >
# > Step 1: Load the dataset
# >
# > Step 2: Build the YOLO network ($\bf{4 points}$)
# >>
# >>  <img src="https://drive.google.com/uc?export=view&id=1c4yOWTZacei0_pFoI47wfxVEhM5Tms8X" alt="no_image" style="width: 800px;"/>
# >>
# >> - Following the YOLO model, you build yolo network
# >> - **Note that our model is different from network of original paper. Please follow above figure.**
# >> - You must fill out the blank in **self.pre_train_net** and **self.post_net** blocks
# >> - All layers use the following Leaky ReLU (0.1 slope for negative part (default=0.01))
# >>
# >>
# >> #### **self.pre_train_net**
# >>
# >>
# >>
# >>| Name       | Filters              | Output Dimension | Padding |
# >>|------------|----------------------|------------------| ------- |
# >>| Conv 1     | 7 x 7 x 64, stride=2 | 224 x 224 x 64   | 3       |
# >>| LeakyReLU  | negative_slop=0.1   | 224 x 224 x 64   |         |
# >>| Max Pool 1 | 2 x 2, stride=2      | 112 x 112 x 64   |         |
# >>|
# >>| Conv 2     | 3 x 3 x 192          | 112 x 112 x 192  | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 112 x 112 x 192  |         |
# >>| Max Pool 2 | 2 x 2, stride=2      | 56 x 56 x 192    |         |
# >>|
# >>| Conv 3     | 1 x 1 x 128          | 56 x 56 x 128    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 128    |         |
# >>| Conv 4     | 3 x 3 x 256          | 56 x 56 x 256    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 256    |         |
# >>| Conv 5     | 1 x 1 x 256          | 56 x 56 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 256    |         |
# >>| Conv 6     | 3 x 3 x 512          | 56 x 56 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 512    |         |
# >>| Max Pool 3 | 2 x 2, stride=2      | 28 x 28 x 512    |         |
# >>|
# >>| Conv 7     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 8     | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 9     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 10    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 11    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 12    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 13    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 14    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 15    | 1 x 1 x 512          | 28 x 28 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 16    | 3 x 3 x 1024         | 28 x 28 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 1024   |         |
# >>| Max Pool 4 | 2 x 2, stride=2      | 14 x 14 x 1024   |         |
# >>|
# >>| Conv 17    | 1 x 1 x 512          | 14 x 14 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 14 x 14 x 512    |         |
# >>| Conv 18    | 3 x 3 x 1024         | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 14 x 14 x 1024   |         |
# >>
# >> #### **self.post_net**
# >>
# >>| Name      | Filters                | Output Dimension | Padding |
# >>|-----------|------------------------|------------------| ------- |
# >>| Conv 19   | 3 x 3 x 1024           | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 14 x 14 x 1024   |         |
# >>| Conv 20   | 3 x 3 x 1024, stride=2 | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>| Conv 21   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>| Conv 22   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>
# > Step 3: Loss function ($\bf{6 points}$)
# >
# >> - Fill out the code considering the loss function in YOLO
# >> - The loss function is composed like below
# >> <img src="https://drive.google.com/uc?export=view&id=1QcAP__J50M379GAul7SlhAzzU551tuDj" alt="no_image" style="width: 600px;"/>
# >>
# >> - $\mathbb{1}_{obj}$ is defined as follows:
# >>    - 1, if an object is present in grid cell $i$ and the $j$th bounding box predictor
# >>    - 0, otherwise
# >>
# >> - YOLO predicts multiple bounding boxes per grid cell (in our case, 2 bounding boxes are predicted)
# >> - In train stage, YOLO requires one bounding box predictor to be responsible for each object
# >> - The code assigns one predictor to be "responsible" for predicting an object where the predictor has the highest IOU with the ground truth
# >> - The loss function is divided into the three sub-sections
# >>    1. Classification ( $\bf{6}$ classes ) ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=13mnxg_GNtbWnYLpe1P6zopf693zTYe22" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Similar to sum-squared error for classification except for $\mathbb{1}_{obj}$ term
# >>
# >>       - Note that, we do not penalize classification error when no object is present on the cell (by $\mathbb{1}_{obj}$ term)
# >>
# >>    2. No object appears in cell ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1R74HzbRLoX2K5zun8XSLAnRQlKq25XFV" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Compute the loss associated with the confidence score for each bounding box predictor
# >>
# >>       - $\mathbb{1}_{noobj}$ is equal to one when there is no object in the cell, and 0 other wise
# >>    3. Bounding box coordinates (x,y,h,w) regression (4 scalars), and Object confidence ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1lXs5lHUiXGxgMRNCiViY6SyRDL52gQsy" alt="no_image" style="width: 600px;"/>
# >>
# >>       - Compute the loss realted to the predicted bounding box position $(x,y)$ and width/height $(w,h)$
# >>
# >>       - Note that width/height are adapted square root before computing the loss
# >>
# >>       - In order to solve the problem that small deviations in large boxes matter less than in small boxes
# >>
# >>       - Compute the loss associated with the confidence score for the cell which is responsible for the object
# >>
# >> - Following the paper, $\lambda_{coord} = 5$ and $\lambda_{noobj} = 0.5$
# >>
# > Step 4: Train Model ($\bf{2 points}$)
# >>
# >> - Based on the above code, you build train code on your own
# >> - The necessary things are provided (e.g., *optimizer* and *num_epoch*)
# >> - Note that, we offer the pre-trained model (0.685 mAP) since it requires large training time.
# >> - If you construct your code correctly, the performance of mAP will be over 0.7 mAP in 10 epochs (about 15 minitues.)
# >>
# > Step 5: Inference
# >>
# >> - We offer the test code in below
# >> - You can check the qualitative results using the visualization code
# >> - The quantitative results will be evaluated by using the mAP code
# >> - If the performance of mAP is significantly decreased from the pre-trained model (0.685 mAP), your code will be wrong
# >>
# >> Step 5-1: Inference (Visualization)
# >>
# >> Step 5-2: Inference (mAP)

# %% [markdown]
# ### Step 1. Load the dataset

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

class YoloDataset(data.Dataset):
    def __init__(self, root, list_file, train, transform=None):
        self.image_size = 448
        self.root = root
        self.train = train
        self.transform = transform
        self.fnames = []
        self.boxes = []
        self.labels = []
        self.color_jitter = Compose([transforms.ColorJitter(brightness=0.1,contrast=0.1, saturation=0.1, hue=0.1),
                                                 transforms.ToTensor()])
        self.plain = Compose([transforms.ToTensor()])
        self.resize = Compose([transforms.ToPILImage(),
                              transforms.Resize((self.image_size, self.image_size)),
                              transforms.ToTensor()])
        
        with open(list_file) as f:
            lines = f.readlines()
            
        for line in lines:
            splited = line.strip().split()
            self.fnames.append(splited[0])
            num_boxes = (len(splited) - 1) // 5
            box = []
            label = []
            for i in range(num_boxes):
                x_min = float(splited[1+5*i])
                y_min = float(splited[2+5*i])
                x_max = float(splited[3+5*i])
                y_max = float(splited[4+5*i])
                c = splited[5+5*i]
                box.append([x_min, y_min, x_max, y_max])
                label.append(int(c)+1)
            self.boxes.append(torch.Tensor(box))
            self.labels.append(torch.LongTensor(label))
        self.num_samples = len(self.boxes)
        
    def img_pre_process(self, img, boxes, labels):
        
        if random.random() < 0.5:
            im_lr = np.fliplr(img).copy()
            height, width, c = img.shape
            x_min = width - boxes[:, 2]
            x_max = width - boxes[:, 0]
            boxes[:,0] = x_min
            boxes[:,2] = x_max
            img = im_lr
        
        ## Converting the image and box information scaling
        if random.random() < 0.5:
            scale = random.uniform(0.8, 1.2)
            height, width, c = img.shape
            img = cv2.resize(img, (int(width * scale), height))
            boxes = boxes * torch.FloatTensor([[scale, 1, scale, 1]]).expand_as(boxes)
            
        ## Image translation
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            shifted_img = np.zeros((height, width, c), dtype=img.dtype)
            
            w_range = int(random.uniform(-width*0.2, width*0.2))
            h_range = int(random.uniform(-height*0.2, height*0.2))
            
            if w_range<0 and h_range<0:
                shifted_img[:height+h_range,:width+w_range,:] = img[-h_range:,-w_range:,:]
                
            elif w_range<0 and h_range>=0:
                shifted_img[h_range:,:width+w_range,:] = img[:height-h_range,-w_range:,:]
            
            elif w_range>=0 and h_range>=0:
                shifted_img[h_range:,w_range:,:] = img[:height-h_range,:width-w_range,:]
                
            elif w_range>=0 and h_range<0:
                shifted_img[:height+h_range,w_range:,:] = img[-h_range:,:width-w_range,:]
                
            wh_range = torch.FloatTensor([[w_range, h_range]]).expand_as(center)
            center = center + wh_range
            
            mask1 = (center[:,0] > 0) & (center[:,0] < width)
            mask2 = (center[:,1] > 0) & (center[:,1] < height)
            mask = (mask1 & mask2).view(-1,1)
            
            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)
            
            if len(boxes_in) != 0:
                box_shift = torch.FloatTensor([[w_range, h_range, w_range, h_range]]).expand_as(boxes_in)
                boxes_in = boxes_in + box_shift
                
                labels_in = labels[mask.view(-1)]
                labels = labels_in
                img = shifted_img
                boxes = boxes_in
        
        ## Image cropping
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            h = int(random.uniform(0.6*height,height))
            w = int(random.uniform(0.6*width,width))
            x = int(random.uniform(0,width-w))
            y = int(random.uniform(0,height-h))
            
            center = center - torch.FloatTensor([[x, y]]).expand_as(center)
            mask1 = (center[:,0]>0) & (center[:,0]<w)
            mask2 = (center[:,1]>0) & (center[:,1]<h)
            mask = (mask1 & mask2).view(-1, 1)
            
            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)
            
            if (len(boxes_in)!=0):
                box_shift = torch.FloatTensor([x,y,x,y]).expand_as(boxes_in)

                boxes_in = boxes_in - box_shift
                boxes_in[:,0]=boxes_in[:,0].clamp_(min=0,max=w)
                boxes_in[:,2]=boxes_in[:,2].clamp_(min=0,max=w)
                boxes_in[:,1]=boxes_in[:,1].clamp_(min=0,max=h)
                boxes_in[:,3]=boxes_in[:,3].clamp_(min=0,max=h)

                labels = labels[mask.view(-1)]
                img_cropped = img[y:y+h, x:x+w, :]
                boxes = boxes_in
                img = img_cropped
        
        return img, boxes, labels

    def generate_target(self, img, boxes, labels):
        grid_size = 7
        h,w,_ = img.shape
        boxes /= torch.Tensor([w,h,w,h]).expand_as(boxes) # Converting the box size 0 ~ 1
        target = torch.zeros((grid_size, grid_size, 30)) 
        cell_size = 1./grid_size 

        wh = boxes[:,2:] - boxes[:,:2]
        cxcy = (boxes[:,2:] + boxes[:,:2]) / 2
        
        for i in range(cxcy.size()[0]):
            cxcy_sample = cxcy[i] # center pixel 
            ij = (cxcy_sample/cell_size).ceil()-1 
            target[int(ij[1]),int(ij[0]),4] = 1
            target[int(ij[1]),int(ij[0]),9] = 1
            target[int(ij[1]),int(ij[0]),int(labels[i])+9] = 1
            
            xy = ij*cell_size 
            delta_xy = (cxcy_sample -xy)/cell_size # Converting delta_xy to the size 
                                                   # relative to the bounds of the grid cell
            target[int(ij[1]),int(ij[0]),2:4] = wh[i]
            target[int(ij[1]),int(ij[0]),:2] = delta_xy
            target[int(ij[1]),int(ij[0]),7:9] = wh[i]
            target[int(ij[1]),int(ij[0]),5:7] = delta_xy
            
        return target
    
    def RandomBrightness(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            v = v*adjust
            v = np.clip(v, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomSaturation(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            s = s*adjust
            s = np.clip(s, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomHue(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            h = h*adjust
            h = np.clip(h, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr

    def randomBlur(self,bgr):
        if random.random()<0.5:
            bgr = cv2.blur(bgr,(5,5))
        return bgr
        
    def __getitem__(self, idx):
        fname = self.fnames[idx]
        img = cv2.imread(os.path.join(self.root+fname))
        boxes = self.boxes[idx].clone()
        labels = self.labels[idx].clone()

        if self.train:
            img = self.randomBlur(img)
            img = self.RandomBrightness(img)
            img = self.RandomHue(img)
            img = self.RandomSaturation(img)
            img, boxes, labels = self.img_pre_process(img, boxes, labels)
            
        target = self.generate_target(img, boxes, labels) # 7x7x30
        
        # Image processing
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        img = self.plain(img)
        img = self.resize(img)
        img = 2 * img - 1
        
        return img, target
    
    def __len__(self):
        return self.num_samples

# %% [markdown]
# ### Step 2. Build the YOLO network (2 points)

# %% [markdown]
# > You should build model using nn.Sequential. Otherwise, problem arises when loading pretrained weights.

# %%
class YOLO(nn.Module):
    def __init__(self):
        super(YOLO, self).__init__()
        
        self.pre_train_net = nn.Sequential(
            ################
            ### Fill out ###
            ##1##
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=7, stride=2, padding=3),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            ##2##
            nn.Conv2d(in_channels=64, out_channels=192, kernel_size=3, padding=1),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            ##3##
            nn.Conv2d(in_channels=192, out_channels=128, kernel_size=1, padding=0),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            ##4##
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            ##5##
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=1, padding=0),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            ##6##
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=1),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            ##7##
            nn.Conv2d(in_channels=512, out_channels=256, kernel_size=1, padding=0),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            ##8##
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=1),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            ##9##
            nn.Conv2d(in_channels=512, out_channels=256, kernel_size=1, padding=0),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            ##10##
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=1),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            ##11##
            nn.Conv2d(in_channels=512, out_channels=256, kernel_size=1, padding=0),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            ##12##
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=1),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            ##13##
            nn.Conv2d(in_channels=512, out_channels=256, kernel_size=1, padding=0),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            ##14##
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=1),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            ##15##
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=1, padding=0),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            ##16##
            nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3, padding=1),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            ##17##
            nn.Conv2d(in_channels=1024, out_channels=512, kernel_size=1, padding=0),
            nn.LeakyReLU(negative_slope=0.1, inplace=False),
            ##18##
            nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=3, padding=1),
            nn.LeakyReLU(negative_slope=0.1, inplace=False)
            ################
            
        )
        
        self.post_net = nn.Sequential(
            ################
            ### Fill out ###
            ##19##
            nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=False),
            ##20##
            nn.Conv2d(in_channels=1024, out_channels=1024, stride=2, kernel_size=3, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=False),
            ##21##
            nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=False),
            ##22##
            nn.Conv2d(in_channels=1024, out_channels=1024, kernel_size=3, padding=1),
            nn.LeakyReLU(negative_slope=0.01, inplace=False),
            ################
        )
        
        self.FC1 = nn.Sequential(
            nn.Linear(50176, 4096),
            nn.LeakyReLU(),
            nn.Dropout()
        )
        
        self.FC2 = nn.Sequential(
            nn.Linear(4096, 1470)
        )
        
        self.pre_train_net.cuda()
        self.post_net.cuda()
        self.FC1.cuda()
        self.FC2.cuda()
        
        self._initialize_weights()

    def forward(self, x):
        output = self.pre_train_net(x)
        output = self.post_net(output)

        # Ready to going for FC layer
        output = output.view(output.size(0), -1)

        output = self.FC1(output)
        output = self.FC2(output)

        output = output.view(output.size(0), 7, 7, 30)
        # Converting the output shape to the (batch_size, 7, 7, 30)
        output = F.relu(output)

        return output
    
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()

# %% [markdown]
# ### Step 3. Loss function (6 points)

# %%
class yoloLoss(nn.Module):
    def __init__(self,l_coord,l_noobj):
        super(yoloLoss,self).__init__()
        self.l_coord = l_coord # Lambda noobj
        self.l_noobj = l_noobj # Lambda coord
    
    def compute_prob_error(self, pred, target): ## classification error
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7, 1]
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        
        ################
        ### Fill out ###
        # Similar to codes from function, contain_obj_error
        # Output vector should be contain 30
        prediction = pred[contain].view(-1, 30)
        classes_p = prediction[:, 10:]
        targeting = target[contain].view(-1, 30)
        classes_t = targeting[:, 10:]
        # Get the Loss Function, MSE Loss
        prob_loss = F.mse_loss(classes_p, classes_t, size_average=False)
        ################
        
        return prob_loss
    
    def not_contain_obj_error(self, pred, target): ## Error where no object appears in cell
        not_contain = target[:,:,:,4] == 0 # [Batch_size, 7, 7, 1]
        not_contain = not_contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        
        ################
        ### Fill out ###
        # Similar to codes from function, contain_obj_error
        # Output vector should contain 30
        noobj_p = pred[not_contain].view(-1,30)
        noobj_t = target[not_contain].view(-1,30)
        
        # Create Mask
        noobj_p_temp = torch.cuda.ByteTensor(noobj_p.size())
        noobj_p_temp.zero_()
        noobj_p_temp[:,4]=1
        noobj_p_temp[:,9]=1
        # Take confidence score for each bounding box predictor
        conf_p = noobj_p[noobj_p_temp]
        conf_t = noobj_t[noobj_p_temp]
        # Get Loss Functions, MSE Loss.
        noobj_loss1 = F.mse_loss(conf_p, conf_t, size_average=False)
        ################
        
        return noobj_loss1
    
    
    def contain_obj_error(self, pred, target): ##
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7, 1]
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]
        
        contain_pred = pred[contain].contiguous().view(-1,30) # Only cell which contains the object are remained
        box_pred = contain_pred[:,:10].contiguous().view(-1,5) # Reshaping
        
        contain_target = target[contain].contiguous().view(-1,30)
        box_target = contain_target[:,:10].contiguous().view(-1,5)
        
        # Note that, We assign one predictor to be "responsible" for predicting 
        # an object based on which prediction has the highest current IOU with the ground truth
        # Then, other prediction is "not responsible" for predicting an object
        # That component is included in "contain_noobj_mask variables
        
        contain_obj_mask = torch.cuda.ByteTensor(box_target.size()).zero_() # Create the mask
        contain_noobj_mask = torch.cuda.ByteTensor(box_target.size()).zero_() 
        
        target_iou_gt = torch.zeros(box_target[:,0].size()).cuda() # In order to save the IoU for confidence 
                                                                   # of the cell which contains object
        
        # Bounding Box
        for i in range(0, box_target.size()[0], 2):
            box_p = box_pred[i:i+2] # For 2 bounding boxes information
            box_p_coord = Variable(torch.FloatTensor(box_p.size())) # Box coordinate (x_min, y_min, x_max, y_max)
            
            box_p_coord[:,:2] = box_p[:,:2]/14.-box_p[:,2:4]/2## Fill out 
            box_p_coord[:,2:4] = box_p[:,:2]/14.+box_p[:,2:4]/2## Fill out
            
            box_t = box_target[i].contiguous().view(-1,5)
            box_t_coord = Variable(torch.FloatTensor(box_t.size()))
            box_t_coord[:,:2] = box_t[:,:2]/14.-box_t[:,2:4]/2## Fill out
            box_t_coord[:,2:4] = box_t[:,:2]/14.+box_t[:,2:4]/2## Fill out
            
            iou = self.compute_iou(box_p_coord[:,:4], box_t_coord[:,:4]) # [2,]
                                                      # compute IoU between prediction and target boxes, 
            
            gt_iou, max_idx = iou.max(0)
            contain_obj_mask[i+max_idx] = 1
            contain_noobj_mask[i+1-max_idx] = 1
            
            target_iou_gt[i+max_idx] = gt_iou.data.cuda()
            
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        target_iou_gt = target_iou_gt.to(device)
        
        ## For the cell which contains object
        contain_box_pred = box_pred[contain_obj_mask].view(-1, 5)## Fill out 
        
        ## For the cell which does not contain object
        not_contain_box_pred = box_pred[contain_noobj_mask].view(-1, 5) ## Fill out 

        ## For target domain 
        contain_box_target = box_target[contain_obj_mask].view(-1, 5)## Fill out
        not_contain_box_target = box_target[contain_noobj_mask].view(-1,5)## Fill out
        not_contain_box_target[:,4] = 0
        
        ## For the GT IoU 
        contain_iou_target = target_iou_gt[contain_obj_mask[:,4]]## Fill out 
        
        obj_loss = F.mse_loss(contain_box_pred[:,4], contain_iou_target, size_average=False)
        xy_loss = F.mse_loss(contain_box_pred[:,:2], contain_box_target[:,:2], size_average=False)
        wh_loss = F.mse_loss(torch.sqrt(contain_box_pred[:,2:4]), torch.sqrt(contain_box_target[:,2:4]), size_average=False)
        noobj_loss2 = F.mse_loss(not_contain_box_pred[:,4], not_contain_box_target[:,4], size_average=False)
        
        return obj_loss, xy_loss, wh_loss, noobj_loss2
        
    def compute_iou(self, box_p, box_t):
        
        pred_area = (box_p[:,2] - box_p[:,0]) * (box_p[:,3] - box_p[:,1]) # [2,]
        target_area = (box_t[:,2] - box_t[:,0]) * (box_t[:,3] - box_t[:,1]) #[1,]
        
        box_p = box_p.unsqueeze(1).expand(2,1,4)
        box_t = box_t.unsqueeze(0).expand(2,1,4)
        
        inter_lt = torch.max(box_p[:,:,:2], box_t[:,:,:2]) # [2,1,2]
        
        inter_rb = torch.min(box_p[:,:,2:], box_t[:,:,2:]) # [2,1,2]
        
        wh = inter_rb - inter_lt # [2,1,2]
        wh[wh<0] = 0 
        
        inter_area = wh[:,:,0] * wh[:,:,1] # [2,1]
        pred_area = pred_area.unsqueeze(1).expand_as(inter_area)
        target_area = target_area.unsqueeze(0).expand_as(inter_area)
        
        iou = inter_area / (pred_area + target_area - inter_area)
        
        return iou
    
        
    
    def forward(self,pred,target):

        batch_size = pred.size()[0]
        
        noobj_loss1 = self.not_contain_obj_error(pred, target)
        prob_loss = self.compute_prob_error(pred, target)
        obj_loss, xy_loss, wh_loss, noobj_loss2 = self.contain_obj_error(pred, target)
        
        total_loss = (self.l_coord*(xy_loss + wh_loss) + obj_loss + self.l_noobj*(noobj_loss1 + noobj_loss2) + prob_loss)
        
        return total_loss / batch_size

# %% [markdown]
# ### Step 4. Train the model

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
file_root = 'dataset/lab8/all_img/'
train_dataset = YoloDataset(root=file_root, list_file='codes_util/lab8/Generate_dataset/voc2007+2012.txt', train=True)
train_loader = DataLoader(train_dataset, batch_size=10, shuffle=True, num_workers=4)

model = YOLO()
state_dict = torch.load('pretrain/lab8/pre_train.pt')
model.load_state_dict(state_dict['state_dict'])

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

learning_rate = 1e-4
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
optimizer.load_state_dict(state_dict['optimizer'])

print('pre_train_complete')
criterion = yoloLoss(l_coord=5,l_noobj=0.5)

best = 1e+30
num_epochs = 15
print("training start!")

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
        
    for i, (images, target) in enumerate(train_loader):
        images = images.to(device)
        target = target.to(device)
        
        pred = model(images)
        loss = criterion(pred, target)
        
        total_loss += loss.item()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 10 == 0:
            print('Epoch [%d/%d], Iter [%d,%d] Loss:%.4f, average_loss: %.4f' % (epoch+1, num_epochs, i+1, len(train_loader), loss.item(), total_loss / (i+1)))
# Out:
# pre_train_complete
# training start!
# Epoch [1/15], Iter [10,430] Loss:0.7517, average_loss: 0.9936
# Epoch [1/15], Iter [20,430] Loss:0.4870, average_loss: 1.0519
# Epoch [1/15], Iter [30,430] Loss:1.1350, average_loss: 0.9660
# Epoch [1/15], Iter [40,430] Loss:1.2376, average_loss: 0.9438
# Epoch [1/15], Iter [50,430] Loss:0.6853, average_loss: 0.9126
# Epoch [1/15], Iter [60,430] Loss:0.6285, average_loss: 0.9042
# Epoch [1/15], Iter [70,430] Loss:0.9785, average_loss: 0.9167
# Epoch [1/15], Iter [80,430] Loss:0.9086, average_loss: 0.9216
# Epoch [1/15], Iter [90,430] Loss:1.0287, average_loss: 0.9113
# Epoch [1/15], Iter [100,430] Loss:0.4564, average_loss: 0.9044
# Epoch [1/15], Iter [110,430] Loss:0.9254, average_loss: 0.9049
# Epoch [1/15], Iter [120,430] Loss:0.6306, average_loss: 0.8890
# Epoch [1/15], Iter [130,430] Loss:0.4823, average_loss: 0.8895
# Epoch [1/15], Iter [140,430] Loss:0.7292, average_loss: 0.8821
# Epoch [1/15], Iter [150,430] Loss:0.7897, average_loss: 0.8815
# Epoch [1/15], Iter [160,430] Loss:0.5305, average_loss: 0.8784
# Epoch [1/15], Iter [170,430] Loss:0.6093, average_loss: 0.8705
# Epoch [1/15], Iter [180,430] Loss:1.1560, average_loss: 0.8662
# Epoch [1/15], Iter [190,430] Loss:0.7923, average_loss: 0.8593
# Epoch [1/15], Iter [200,430] Loss:0.9990, average_loss: 0.8589
# Epoch [1/15], Iter [210,430] Loss:0.8630, average_loss: 0.8569
# Epoch [1/15], Iter [220,430] Loss:1.1275, average_loss: 0.8534
# Epoch [1/15], Iter [230,430] Loss:0.5788, average_loss: 0.8470
# Epoch [1/15], Iter [240,430] Loss:0.9645, average_loss: 0.8418
# Epoch [1/15], Iter [250,430] Loss:0.6353, average_loss: 0.8345
# Epoch [1/15], Iter [260,430] Loss:0.7146, average_loss: 0.8275
# Epoch [1/15], Iter [270,430] Loss:0.5758, average_loss: 0.8288
# Epoch [1/15], Iter [280,430] Loss:0.5680, average_loss: 0.8287
# Epoch [1/15], Iter [290,430] Loss:0.5766, average_loss: 0.8297
# Epoch [1/15], Iter [300,430] Loss:0.9315, average_loss: 0.8287
# Epoch [1/15], Iter [310,430] Loss:1.0660, average_loss: 0.8280
# Epoch [1/15], Iter [320,430] Loss:0.8668, average_loss: 0.8243
# Epoch [1/15], Iter [330,430] Loss:0.9175, average_loss: 0.8269
# Epoch [1/15], Iter [340,430] Loss:0.8062, average_loss: 0.8208
# Epoch [1/15], Iter [350,430] Loss:1.0049, average_loss: 0.8202
# Epoch [1/15], Iter [360,430] Loss:0.7063, average_loss: 0.8177
# Epoch [1/15], Iter [370,430] Loss:0.5042, average_loss: 0.8218
# Epoch [1/15], Iter [380,430] Loss:0.6957, average_loss: 0.8220
# Epoch [1/15], Iter [390,430] Loss:0.5424, average_loss: 0.8194
# Epoch [1/15], Iter [400,430] Loss:0.7499, average_loss: 0.8137
# Epoch [1/15], Iter [410,430] Loss:0.9419, average_loss: 0.8133
# Epoch [1/15], Iter [420,430] Loss:1.2705, average_loss: 0.8135
# Epoch [1/15], Iter [430,430] Loss:0.6610, average_loss: 0.8126
# Epoch [2/15], Iter [10,430] Loss:1.3941, average_loss: 0.8200
# Epoch [2/15], Iter [20,430] Loss:0.8759, average_loss: 0.8348
# Epoch [2/15], Iter [30,430] Loss:0.8216, average_loss: 0.8609
# Epoch [2/15], Iter [40,430] Loss:0.3916, average_loss: 0.8312
# Epoch [2/15], Iter [50,430] Loss:0.3949, average_loss: 0.8093
# Epoch [2/15], Iter [60,430] Loss:0.7229, average_loss: 0.7943
# Epoch [2/15], Iter [70,430] Loss:0.6459, average_loss: 0.7893
# Epoch [2/15], Iter [80,430] Loss:0.9456, average_loss: 0.7975
# Epoch [2/15], Iter [90,430] Loss:0.9591, average_loss: 0.7837
# Epoch [2/15], Iter [100,430] Loss:0.4318, average_loss: 0.7939
# Epoch [2/15], Iter [110,430] Loss:1.1607, average_loss: 0.7850
# Epoch [2/15], Iter [120,430] Loss:0.9328, average_loss: 0.7892
# Epoch [2/15], Iter [130,430] Loss:0.4973, average_loss: 0.7785
# Epoch [2/15], Iter [140,430] Loss:0.7807, average_loss: 0.7736
# Epoch [2/15], Iter [150,430] Loss:0.6649, average_loss: 0.7723
# Epoch [2/15], Iter [160,430] Loss:0.6553, average_loss: 0.7680
# Epoch [2/15], Iter [170,430] Loss:0.5842, average_loss: 0.7704
# Epoch [2/15], Iter [180,430] Loss:1.0552, average_loss: 0.7749
# Epoch [2/15], Iter [190,430] Loss:0.4154, average_loss: 0.7670
# Epoch [2/15], Iter [200,430] Loss:0.5755, average_loss: 0.7636
# Epoch [2/15], Iter [210,430] Loss:1.0267, average_loss: 0.7619
# Epoch [2/15], Iter [220,430] Loss:0.7533, average_loss: 0.7525
# Epoch [2/15], Iter [230,430] Loss:0.4974, average_loss: 0.7535
# Epoch [2/15], Iter [240,430] Loss:0.4255, average_loss: 0.7534
# Epoch [2/15], Iter [250,430] Loss:0.5213, average_loss: 0.7530
# Epoch [2/15], Iter [260,430] Loss:0.6930, average_loss: 0.7531
# Epoch [2/15], Iter [270,430] Loss:1.1183, average_loss: 0.7554
# Epoch [2/15], Iter [280,430] Loss:0.4307, average_loss: 0.7499
# Epoch [2/15], Iter [290,430] Loss:0.5818, average_loss: 0.7515
# Epoch [2/15], Iter [300,430] Loss:0.2356, average_loss: 0.7573
# Epoch [2/15], Iter [310,430] Loss:0.3982, average_loss: 0.7567
# Epoch [2/15], Iter [320,430] Loss:1.0392, average_loss: 0.7574
# Epoch [2/15], Iter [330,430] Loss:1.6535, average_loss: 0.7590
# Epoch [2/15], Iter [340,430] Loss:0.5942, average_loss: 0.7613
# Epoch [2/15], Iter [350,430] Loss:1.1075, average_loss: 0.7643
# Epoch [2/15], Iter [360,430] Loss:0.9725, average_loss: 0.7644
# Epoch [2/15], Iter [370,430] Loss:0.5815, average_loss: 0.7661
# Epoch [2/15], Iter [380,430] Loss:0.9590, average_loss: 0.7688
# Epoch [2/15], Iter [390,430] Loss:0.6507, average_loss: 0.7671
# Epoch [2/15], Iter [400,430] Loss:0.5633, average_loss: 0.7657
# Epoch [2/15], Iter [410,430] Loss:0.3778, average_loss: 0.7606
# Epoch [2/15], Iter [420,430] Loss:0.4297, average_loss: 0.7566
# Epoch [2/15], Iter [430,430] Loss:1.0162, average_loss: 0.7549
# Epoch [3/15], Iter [10,430] Loss:0.8618, average_loss: 0.6384
# Epoch [3/15], Iter [20,430] Loss:0.8244, average_loss: 0.6719
# Epoch [3/15], Iter [30,430] Loss:0.4735, average_loss: 0.6680
# Epoch [3/15], Iter [40,430] Loss:0.7318, average_loss: 0.7104
# Epoch [3/15], Iter [50,430] Loss:0.7579, average_loss: 0.7568
# Epoch [3/15], Iter [60,430] Loss:1.0753, average_loss: 0.7636
# Epoch [3/15], Iter [70,430] Loss:0.6517, average_loss: 0.7533
# Epoch [3/15], Iter [80,430] Loss:1.1242, average_loss: 0.7662
# Epoch [3/15], Iter [90,430] Loss:0.5734, average_loss: 0.7722
# Epoch [3/15], Iter [100,430] Loss:0.7616, average_loss: 0.7628
# Epoch [3/15], Iter [110,430] Loss:0.7544, average_loss: 0.7712
# Epoch [3/15], Iter [120,430] Loss:1.1743, average_loss: 0.7707
# Epoch [3/15], Iter [130,430] Loss:0.7677, average_loss: 0.7710
# Epoch [3/15], Iter [140,430] Loss:0.4942, average_loss: 0.7749
# Epoch [3/15], Iter [150,430] Loss:0.6089, average_loss: 0.7660
# Epoch [3/15], Iter [160,430] Loss:0.6162, average_loss: 0.7622
# Epoch [3/15], Iter [170,430] Loss:0.4316, average_loss: 0.7536
# Epoch [3/15], Iter [180,430] Loss:0.4490, average_loss: 0.7532
# Epoch [3/15], Iter [190,430] Loss:0.4230, average_loss: 0.7522
# Epoch [3/15], Iter [200,430] Loss:0.9154, average_loss: 0.7521
# Epoch [3/15], Iter [210,430] Loss:0.7168, average_loss: 0.7526
# Epoch [3/15], Iter [220,430] Loss:1.0094, average_loss: 0.7528
# Epoch [3/15], Iter [230,430] Loss:0.6927, average_loss: 0.7528
# Epoch [3/15], Iter [240,430] Loss:0.7109, average_loss: 0.7576
# Epoch [3/15], Iter [250,430] Loss:0.8065, average_loss: 0.7524
# Epoch [3/15], Iter [260,430] Loss:1.0844, average_loss: 0.7516
# Epoch [3/15], Iter [270,430] Loss:0.5766, average_loss: 0.7463
# Epoch [3/15], Iter [280,430] Loss:0.3487, average_loss: 0.7511
# Epoch [3/15], Iter [290,430] Loss:0.9822, average_loss: 0.7476
# Epoch [3/15], Iter [300,430] Loss:0.4721, average_loss: 0.7439
# Epoch [3/15], Iter [310,430] Loss:0.5501, average_loss: 0.7439
# Epoch [3/15], Iter [320,430] Loss:0.3541, average_loss: 0.7397
# Epoch [3/15], Iter [330,430] Loss:0.8169, average_loss: 0.7377
# Epoch [3/15], Iter [340,430] Loss:0.6154, average_loss: 0.7337
# Epoch [3/15], Iter [350,430] Loss:0.3914, average_loss: 0.7287
# Epoch [3/15], Iter [360,430] Loss:0.8465, average_loss: 0.7314
# Epoch [3/15], Iter [370,430] Loss:0.5822, average_loss: 0.7313
# Epoch [3/15], Iter [380,430] Loss:0.8885, average_loss: 0.7313
# Epoch [3/15], Iter [390,430] Loss:0.6945, average_loss: 0.7296
# Epoch [3/15], Iter [400,430] Loss:0.8063, average_loss: 0.7275
# Epoch [3/15], Iter [410,430] Loss:0.4634, average_loss: 0.7279
# Epoch [3/15], Iter [420,430] Loss:0.7325, average_loss: 0.7252
# Epoch [3/15], Iter [430,430] Loss:0.3970, average_loss: 0.7263
# Epoch [4/15], Iter [10,430] Loss:0.5903, average_loss: 0.7537
# Epoch [4/15], Iter [20,430] Loss:0.5016, average_loss: 0.6782
# Epoch [4/15], Iter [30,430] Loss:0.5936, average_loss: 0.7048
# Epoch [4/15], Iter [40,430] Loss:0.3458, average_loss: 0.6913
# Epoch [4/15], Iter [50,430] Loss:1.1318, average_loss: 0.7026
# Epoch [4/15], Iter [60,430] Loss:0.9827, average_loss: 0.6927
# Epoch [4/15], Iter [70,430] Loss:1.5784, average_loss: 0.7267
# Epoch [4/15], Iter [80,430] Loss:0.8318, average_loss: 0.7290
# Epoch [4/15], Iter [90,430] Loss:0.5295, average_loss: 0.7197
# Epoch [4/15], Iter [100,430] Loss:0.9109, average_loss: 0.7211
# Epoch [4/15], Iter [110,430] Loss:0.8803, average_loss: 0.7342
# Epoch [4/15], Iter [120,430] Loss:1.0724, average_loss: 0.7394
# Epoch [4/15], Iter [130,430] Loss:0.6731, average_loss: 0.7386
# Epoch [4/15], Iter [140,430] Loss:0.6682, average_loss: 0.7355
# Epoch [4/15], Iter [150,430] Loss:0.5966, average_loss: 0.7395
# Epoch [4/15], Iter [160,430] Loss:0.6811, average_loss: 0.7511
# Epoch [4/15], Iter [170,430] Loss:0.7040, average_loss: 0.7458
# Epoch [4/15], Iter [180,430] Loss:0.7017, average_loss: 0.7368
# Epoch [4/15], Iter [190,430] Loss:0.6565, average_loss: 0.7340
# Epoch [4/15], Iter [200,430] Loss:0.8411, average_loss: 0.7308
# Epoch [4/15], Iter [210,430] Loss:0.5591, average_loss: 0.7237
# Epoch [4/15], Iter [220,430] Loss:0.5366, average_loss: 0.7192
# Epoch [4/15], Iter [230,430] Loss:0.5028, average_loss: 0.7152
# Epoch [4/15], Iter [240,430] Loss:0.6122, average_loss: 0.7151
# Epoch [4/15], Iter [250,430] Loss:0.7444, average_loss: 0.7125
# Epoch [4/15], Iter [260,430] Loss:0.4980, average_loss: 0.7067
# Epoch [4/15], Iter [270,430] Loss:0.9397, average_loss: 0.7077
# Epoch [4/15], Iter [280,430] Loss:0.5431, average_loss: 0.7034
# Epoch [4/15], Iter [290,430] Loss:0.7917, average_loss: 0.7003
# Epoch [4/15], Iter [300,430] Loss:0.4504, average_loss: 0.6975
# Epoch [4/15], Iter [310,430] Loss:0.5399, average_loss: 0.6979
# Epoch [4/15], Iter [320,430] Loss:0.4547, average_loss: 0.6975
# Epoch [4/15], Iter [330,430] Loss:0.4597, average_loss: 0.6958
# Epoch [4/15], Iter [340,430] Loss:0.5403, average_loss: 0.6997
# Epoch [4/15], Iter [350,430] Loss:0.3685, average_loss: 0.7021
# Epoch [4/15], Iter [360,430] Loss:1.0245, average_loss: 0.7050
# Epoch [4/15], Iter [370,430] Loss:0.5293, average_loss: 0.7053
# Epoch [4/15], Iter [380,430] Loss:0.5880, average_loss: 0.7046
# Epoch [4/15], Iter [390,430] Loss:0.3728, average_loss: 0.7045
# Epoch [4/15], Iter [400,430] Loss:0.7962, average_loss: 0.7067
# Epoch [4/15], Iter [410,430] Loss:1.0876, average_loss: 0.7082
# Epoch [4/15], Iter [420,430] Loss:0.5470, average_loss: 0.7069
# Epoch [4/15], Iter [430,430] Loss:0.7140, average_loss: 0.7052
# Epoch [5/15], Iter [10,430] Loss:0.8146, average_loss: 0.8816
# Epoch [5/15], Iter [20,430] Loss:0.5833, average_loss: 0.7855
# Epoch [5/15], Iter [30,430] Loss:0.4849, average_loss: 0.7241
# Epoch [5/15], Iter [40,430] Loss:0.7675, average_loss: 0.7356
# Epoch [5/15], Iter [50,430] Loss:0.7845, average_loss: 0.7207
# Epoch [5/15], Iter [60,430] Loss:0.6751, average_loss: 0.7180
# Epoch [5/15], Iter [70,430] Loss:0.8898, average_loss: 0.7529
# Epoch [5/15], Iter [80,430] Loss:0.3373, average_loss: 0.7444
# Epoch [5/15], Iter [90,430] Loss:0.5686, average_loss: 0.7329
# Epoch [5/15], Iter [100,430] Loss:0.5173, average_loss: 0.7369
# Epoch [5/15], Iter [110,430] Loss:0.5978, average_loss: 0.7394
# Epoch [5/15], Iter [120,430] Loss:0.9472, average_loss: 0.7360
# Epoch [5/15], Iter [130,430] Loss:0.4662, average_loss: 0.7366
# Epoch [5/15], Iter [140,430] Loss:0.5448, average_loss: 0.7404
# Epoch [5/15], Iter [150,430] Loss:0.4882, average_loss: 0.7298
# Epoch [5/15], Iter [160,430] Loss:0.5143, average_loss: 0.7253
# Epoch [5/15], Iter [170,430] Loss:0.6856, average_loss: 0.7375
# Epoch [5/15], Iter [180,430] Loss:0.5445, average_loss: 0.7350
# Epoch [5/15], Iter [190,430] Loss:0.5187, average_loss: 0.7278
# Epoch [5/15], Iter [200,430] Loss:0.5336, average_loss: 0.7247
# Epoch [5/15], Iter [210,430] Loss:0.5617, average_loss: 0.7245
# Epoch [5/15], Iter [220,430] Loss:0.7367, average_loss: 0.7217
# Epoch [5/15], Iter [230,430] Loss:0.6129, average_loss: 0.7175
# Epoch [5/15], Iter [240,430] Loss:1.0823, average_loss: 0.7193
# Epoch [5/15], Iter [250,430] Loss:0.5615, average_loss: 0.7183
# Epoch [5/15], Iter [260,430] Loss:0.7673, average_loss: 0.7165
# Epoch [5/15], Iter [270,430] Loss:0.5105, average_loss: 0.7159
# Epoch [5/15], Iter [280,430] Loss:0.5458, average_loss: 0.7146
# Epoch [5/15], Iter [290,430] Loss:0.8980, average_loss: 0.7169
# Epoch [5/15], Iter [300,430] Loss:0.8991, average_loss: 0.7144
# Epoch [5/15], Iter [310,430] Loss:0.6316, average_loss: 0.7131
# Epoch [5/15], Iter [320,430] Loss:0.8766, average_loss: 0.7160
# Epoch [5/15], Iter [330,430] Loss:0.6890, average_loss: 0.7122
# Epoch [5/15], Iter [340,430] Loss:0.7323, average_loss: 0.7119
# Epoch [5/15], Iter [350,430] Loss:0.8801, average_loss: 0.7102
# Epoch [5/15], Iter [360,430] Loss:1.0648, average_loss: 0.7138
# Epoch [5/15], Iter [370,430] Loss:0.4595, average_loss: 0.7106
# Epoch [5/15], Iter [380,430] Loss:0.4429, average_loss: 0.7083
# Epoch [5/15], Iter [390,430] Loss:0.3574, average_loss: 0.7081
# Epoch [5/15], Iter [400,430] Loss:0.8852, average_loss: 0.7063
# Epoch [5/15], Iter [410,430] Loss:0.4085, average_loss: 0.7109
# Epoch [5/15], Iter [420,430] Loss:0.3349, average_loss: 0.7069
# Epoch [5/15], Iter [430,430] Loss:0.4725, average_loss: 0.7043
# Epoch [6/15], Iter [10,430] Loss:0.6394, average_loss: 0.7145
# Epoch [6/15], Iter [20,430] Loss:0.4215, average_loss: 0.7319
# Epoch [6/15], Iter [30,430] Loss:1.0427, average_loss: 0.7400
# Epoch [6/15], Iter [40,430] Loss:1.0007, average_loss: 0.7539
# Epoch [6/15], Iter [50,430] Loss:0.5362, average_loss: 0.7175
# Epoch [6/15], Iter [60,430] Loss:0.5305, average_loss: 0.7157
# Epoch [6/15], Iter [70,430] Loss:0.6602, average_loss: 0.7098
# Epoch [6/15], Iter [80,430] Loss:0.5994, average_loss: 0.7053
# Epoch [6/15], Iter [90,430] Loss:0.4364, average_loss: 0.6978
# Epoch [6/15], Iter [100,430] Loss:0.6970, average_loss: 0.7015
# Epoch [6/15], Iter [110,430] Loss:0.4935, average_loss: 0.6952
# Epoch [6/15], Iter [120,430] Loss:1.0621, average_loss: 0.7094
# Epoch [6/15], Iter [130,430] Loss:0.5375, average_loss: 0.7028
# Epoch [6/15], Iter [140,430] Loss:0.4126, average_loss: 0.6967
# Epoch [6/15], Iter [150,430] Loss:0.7297, average_loss: 0.6874
# Epoch [6/15], Iter [160,430] Loss:0.5067, average_loss: 0.6847
# Epoch [6/15], Iter [170,430] Loss:0.4573, average_loss: 0.6789
# Epoch [6/15], Iter [180,430] Loss:1.1604, average_loss: 0.6797
# Epoch [6/15], Iter [190,430] Loss:0.5355, average_loss: 0.6772
# Epoch [6/15], Iter [200,430] Loss:0.6438, average_loss: 0.6745
# Epoch [6/15], Iter [210,430] Loss:0.7673, average_loss: 0.6775
# Epoch [6/15], Iter [220,430] Loss:0.4139, average_loss: 0.6799
# Epoch [6/15], Iter [230,430] Loss:0.2952, average_loss: 0.6805
# Epoch [6/15], Iter [240,430] Loss:0.8590, average_loss: 0.6885
# Epoch [6/15], Iter [250,430] Loss:0.5833, average_loss: 0.6876
# Epoch [6/15], Iter [260,430] Loss:1.0946, average_loss: 0.6883
# Epoch [6/15], Iter [270,430] Loss:0.5925, average_loss: 0.6912
# Epoch [6/15], Iter [280,430] Loss:0.5619, average_loss: 0.6857
# Epoch [6/15], Iter [290,430] Loss:0.6147, average_loss: 0.6913
# Epoch [6/15], Iter [300,430] Loss:0.5715, average_loss: 0.6934
# Epoch [6/15], Iter [310,430] Loss:0.4994, average_loss: 0.6893
# Epoch [6/15], Iter [320,430] Loss:0.3293, average_loss: 0.6857
# Epoch [6/15], Iter [330,430] Loss:0.5926, average_loss: 0.6838
# Epoch [6/15], Iter [340,430] Loss:0.4866, average_loss: 0.6824
# Epoch [6/15], Iter [350,430] Loss:1.0607, average_loss: 0.6825
# Epoch [6/15], Iter [360,430] Loss:0.6451, average_loss: 0.6811
# Epoch [6/15], Iter [370,430] Loss:0.9039, average_loss: 0.6845
# Epoch [6/15], Iter [380,430] Loss:0.6183, average_loss: 0.6850
# Epoch [6/15], Iter [390,430] Loss:0.5337, average_loss: 0.6843
# Epoch [6/15], Iter [400,430] Loss:0.6472, average_loss: 0.6880
# Epoch [6/15], Iter [410,430] Loss:1.0044, average_loss: 0.6918
# Epoch [6/15], Iter [420,430] Loss:0.8363, average_loss: 0.6895
# Epoch [6/15], Iter [430,430] Loss:0.8633, average_loss: 0.6918
# Epoch [7/15], Iter [10,430] Loss:0.9614, average_loss: 0.8040
# Epoch [7/15], Iter [20,430] Loss:0.7329, average_loss: 0.7670
# Epoch [7/15], Iter [30,430] Loss:0.6709, average_loss: 0.7148
# Epoch [7/15], Iter [40,430] Loss:0.7121, average_loss: 0.7219
# Epoch [7/15], Iter [50,430] Loss:0.6490, average_loss: 0.7099
# Epoch [7/15], Iter [60,430] Loss:1.0833, average_loss: 0.7062
# Epoch [7/15], Iter [70,430] Loss:0.6250, average_loss: 0.7052
# Epoch [7/15], Iter [80,430] Loss:0.9553, average_loss: 0.7054
# Epoch [7/15], Iter [90,430] Loss:0.5307, average_loss: 0.7195
# Epoch [7/15], Iter [100,430] Loss:1.0797, average_loss: 0.7266
# Epoch [7/15], Iter [110,430] Loss:0.4976, average_loss: 0.7133
# Epoch [7/15], Iter [120,430] Loss:0.3047, average_loss: 0.7072
# Epoch [7/15], Iter [130,430] Loss:0.7235, average_loss: 0.7136
# Epoch [7/15], Iter [140,430] Loss:0.9455, average_loss: 0.7104
# Epoch [7/15], Iter [150,430] Loss:0.7691, average_loss: 0.7053
# Epoch [7/15], Iter [160,430] Loss:0.3322, average_loss: 0.7004
# Epoch [7/15], Iter [170,430] Loss:0.4334, average_loss: 0.6930
# Epoch [7/15], Iter [180,430] Loss:0.6707, average_loss: 0.7004
# Epoch [7/15], Iter [190,430] Loss:0.5538, average_loss: 0.6977
# Epoch [7/15], Iter [200,430] Loss:0.7411, average_loss: 0.6956
# Epoch [7/15], Iter [210,430] Loss:0.4937, average_loss: 0.6910
# Epoch [7/15], Iter [220,430] Loss:0.5193, average_loss: 0.6871
# Epoch [7/15], Iter [230,430] Loss:0.9035, average_loss: 0.6865
# Epoch [7/15], Iter [240,430] Loss:0.4074, average_loss: 0.6815
# Epoch [7/15], Iter [250,430] Loss:0.7571, average_loss: 0.6812
# Epoch [7/15], Iter [260,430] Loss:0.7766, average_loss: 0.6852
# Epoch [7/15], Iter [270,430] Loss:0.8670, average_loss: 0.6854
# Epoch [7/15], Iter [280,430] Loss:0.7272, average_loss: 0.6846
# Epoch [7/15], Iter [290,430] Loss:0.6117, average_loss: 0.6812
# Epoch [7/15], Iter [300,430] Loss:0.3654, average_loss: 0.6797
# Epoch [7/15], Iter [310,430] Loss:0.2633, average_loss: 0.6777
# Epoch [7/15], Iter [320,430] Loss:0.4105, average_loss: 0.6786
# Epoch [7/15], Iter [330,430] Loss:0.6773, average_loss: 0.6854
# Epoch [7/15], Iter [340,430] Loss:0.7654, average_loss: 0.6846
# Epoch [7/15], Iter [350,430] Loss:0.9882, average_loss: 0.6869
# Epoch [7/15], Iter [360,430] Loss:1.0427, average_loss: 0.6860
# Epoch [7/15], Iter [370,430] Loss:1.1662, average_loss: 0.6901
# Epoch [7/15], Iter [380,430] Loss:1.1724, average_loss: 0.6911
# Epoch [7/15], Iter [390,430] Loss:0.4151, average_loss: 0.6937
# Epoch [7/15], Iter [400,430] Loss:0.4122, average_loss: 0.6922
# Epoch [7/15], Iter [410,430] Loss:0.6140, average_loss: 0.6915
# Epoch [7/15], Iter [420,430] Loss:1.0156, average_loss: 0.6929
# Epoch [7/15], Iter [430,430] Loss:0.6706, average_loss: 0.6926
# Epoch [8/15], Iter [10,430] Loss:1.0210, average_loss: 0.7728
# Epoch [8/15], Iter [20,430] Loss:0.3562, average_loss: 0.7400
# Epoch [8/15], Iter [30,430] Loss:1.4412, average_loss: 0.7341
# Epoch [8/15], Iter [40,430] Loss:0.4416, average_loss: 0.7047
# Epoch [8/15], Iter [50,430] Loss:0.8211, average_loss: 0.6715
# Epoch [8/15], Iter [60,430] Loss:0.7683, average_loss: 0.6647
# Epoch [8/15], Iter [70,430] Loss:1.2943, average_loss: 0.6886
# Epoch [8/15], Iter [80,430] Loss:0.5873, average_loss: 0.6819
# Epoch [8/15], Iter [90,430] Loss:0.4835, average_loss: 0.6766
# Epoch [8/15], Iter [100,430] Loss:0.9973, average_loss: 0.6714
# Epoch [8/15], Iter [110,430] Loss:0.4479, average_loss: 0.6701
# Epoch [8/15], Iter [120,430] Loss:0.8452, average_loss: 0.6645
# Epoch [8/15], Iter [130,430] Loss:0.6706, average_loss: 0.6724
# Epoch [8/15], Iter [140,430] Loss:0.6281, average_loss: 0.6758
# Epoch [8/15], Iter [150,430] Loss:0.5650, average_loss: 0.6773
# Epoch [8/15], Iter [160,430] Loss:0.6307, average_loss: 0.6784
# Epoch [8/15], Iter [170,430] Loss:0.7657, average_loss: 0.6814
# Epoch [8/15], Iter [180,430] Loss:0.7091, average_loss: 0.6863
# Epoch [8/15], Iter [190,430] Loss:0.4300, average_loss: 0.6843
# Epoch [8/15], Iter [200,430] Loss:0.4440, average_loss: 0.6813
# Epoch [8/15], Iter [210,430] Loss:1.1375, average_loss: 0.6844
# Epoch [8/15], Iter [220,430] Loss:0.5012, average_loss: 0.6829
# Epoch [8/15], Iter [230,430] Loss:0.9978, average_loss: 0.6837
# Epoch [8/15], Iter [240,430] Loss:0.4281, average_loss: 0.6822
# Epoch [8/15], Iter [250,430] Loss:0.8345, average_loss: 0.6914
# Epoch [8/15], Iter [260,430] Loss:0.8115, average_loss: 0.6880
# Epoch [8/15], Iter [270,430] Loss:0.4892, average_loss: 0.6885
# Epoch [8/15], Iter [280,430] Loss:0.6466, average_loss: 0.6949
# Epoch [8/15], Iter [290,430] Loss:1.0860, average_loss: 0.6934
# Epoch [8/15], Iter [300,430] Loss:0.5202, average_loss: 0.6914
# Epoch [8/15], Iter [310,430] Loss:0.8187, average_loss: 0.6956
# Epoch [8/15], Iter [320,430] Loss:0.6944, average_loss: 0.6927
# Epoch [8/15], Iter [330,430] Loss:0.7525, average_loss: 0.6900
# Epoch [8/15], Iter [340,430] Loss:0.7464, average_loss: 0.6903
# Epoch [8/15], Iter [350,430] Loss:0.8518, average_loss: 0.6900
# Epoch [8/15], Iter [360,430] Loss:0.5734, average_loss: 0.6896
# Epoch [8/15], Iter [370,430] Loss:0.7455, average_loss: 0.6904
# Epoch [8/15], Iter [380,430] Loss:1.1138, average_loss: 0.6912
# Epoch [8/15], Iter [390,430] Loss:0.7433, average_loss: 0.6890
# Epoch [8/15], Iter [400,430] Loss:0.5699, average_loss: 0.6884
# Epoch [8/15], Iter [410,430] Loss:1.0848, average_loss: 0.6869
# Epoch [8/15], Iter [420,430] Loss:0.7329, average_loss: 0.6879
# Epoch [8/15], Iter [430,430] Loss:0.4813, average_loss: 0.6870
# Epoch [9/15], Iter [10,430] Loss:0.7766, average_loss: 0.6280
# Epoch [9/15], Iter [20,430] Loss:0.8063, average_loss: 0.6409
# Epoch [9/15], Iter [30,430] Loss:0.4919, average_loss: 0.6321
# Epoch [9/15], Iter [40,430] Loss:0.9960, average_loss: 0.6702
# Epoch [9/15], Iter [50,430] Loss:0.7133, average_loss: 0.6945
# Epoch [9/15], Iter [60,430] Loss:0.6821, average_loss: 0.6816
# Epoch [9/15], Iter [70,430] Loss:0.6785, average_loss: 0.6713
# Epoch [9/15], Iter [80,430] Loss:0.6905, average_loss: 0.6659
# Epoch [9/15], Iter [90,430] Loss:0.4782, average_loss: 0.6716
# Epoch [9/15], Iter [100,430] Loss:1.0590, average_loss: 0.6658
# Epoch [9/15], Iter [110,430] Loss:0.4115, average_loss: 0.6593
# Epoch [9/15], Iter [120,430] Loss:1.2681, average_loss: 0.6623
# Epoch [9/15], Iter [130,430] Loss:0.9112, average_loss: 0.6612
# Epoch [9/15], Iter [140,430] Loss:0.7792, average_loss: 0.6600
# Epoch [9/15], Iter [150,430] Loss:0.7660, average_loss: 0.6675
# Epoch [9/15], Iter [160,430] Loss:0.5142, average_loss: 0.6719
# Epoch [9/15], Iter [170,430] Loss:0.8832, average_loss: 0.6744
# Epoch [9/15], Iter [180,430] Loss:0.5003, average_loss: 0.6765
# Epoch [9/15], Iter [190,430] Loss:1.1890, average_loss: 0.6824
# Epoch [9/15], Iter [200,430] Loss:1.3961, average_loss: 0.6842
# Epoch [9/15], Iter [210,430] Loss:1.0139, average_loss: 0.6808
# Epoch [9/15], Iter [220,430] Loss:0.5262, average_loss: 0.6818
# Epoch [9/15], Iter [230,430] Loss:0.6104, average_loss: 0.6763
# Epoch [9/15], Iter [240,430] Loss:0.3475, average_loss: 0.6757
# Epoch [9/15], Iter [250,430] Loss:0.7366, average_loss: 0.6755
# Epoch [9/15], Iter [260,430] Loss:0.8878, average_loss: 0.6800
# Epoch [9/15], Iter [270,430] Loss:0.8298, average_loss: 0.6811
# Epoch [9/15], Iter [280,430] Loss:0.8666, average_loss: 0.6793
# Epoch [9/15], Iter [290,430] Loss:0.4698, average_loss: 0.6781
# Epoch [9/15], Iter [300,430] Loss:0.8809, average_loss: 0.6827
# Epoch [9/15], Iter [310,430] Loss:0.2995, average_loss: 0.6820
# Epoch [9/15], Iter [320,430] Loss:0.4782, average_loss: 0.6861
# Epoch [9/15], Iter [330,430] Loss:0.6389, average_loss: 0.6842
# Epoch [9/15], Iter [340,430] Loss:0.7409, average_loss: 0.6849
# Epoch [9/15], Iter [350,430] Loss:0.3956, average_loss: 0.6834
# Epoch [9/15], Iter [360,430] Loss:0.4099, average_loss: 0.6803
# Epoch [9/15], Iter [370,430] Loss:0.4053, average_loss: 0.6801
# Epoch [9/15], Iter [380,430] Loss:0.4664, average_loss: 0.6788
# Epoch [9/15], Iter [390,430] Loss:1.2642, average_loss: 0.6795
# Epoch [9/15], Iter [400,430] Loss:0.6755, average_loss: 0.6791
# Epoch [9/15], Iter [410,430] Loss:0.9485, average_loss: 0.6810
# Epoch [9/15], Iter [420,430] Loss:0.6034, average_loss: 0.6797
# Epoch [9/15], Iter [430,430] Loss:0.7702, average_loss: 0.6797
# Epoch [10/15], Iter [10,430] Loss:0.8557, average_loss: 0.7305
# Epoch [10/15], Iter [20,430] Loss:0.5824, average_loss: 0.6704
# Epoch [10/15], Iter [30,430] Loss:0.6306, average_loss: 0.6488
# Epoch [10/15], Iter [40,430] Loss:0.9588, average_loss: 0.6655
# Epoch [10/15], Iter [50,430] Loss:0.5272, average_loss: 0.6670
# Epoch [10/15], Iter [60,430] Loss:0.7439, average_loss: 0.6618
# Epoch [10/15], Iter [70,430] Loss:0.4894, average_loss: 0.6431
# Epoch [10/15], Iter [80,430] Loss:0.7884, average_loss: 0.6573
# Epoch [10/15], Iter [90,430] Loss:0.4445, average_loss: 0.6533
# Epoch [10/15], Iter [100,430] Loss:0.6283, average_loss: 0.6543
# Epoch [10/15], Iter [110,430] Loss:1.1359, average_loss: 0.6577
# Epoch [10/15], Iter [120,430] Loss:0.7235, average_loss: 0.6617
# Epoch [10/15], Iter [130,430] Loss:0.6151, average_loss: 0.6573
# Epoch [10/15], Iter [140,430] Loss:1.2225, average_loss: 0.6597
# Epoch [10/15], Iter [150,430] Loss:1.0251, average_loss: 0.6721
# Epoch [10/15], Iter [160,430] Loss:0.2631, average_loss: 0.6668
# Epoch [10/15], Iter [170,430] Loss:0.9179, average_loss: 0.6725
# Epoch [10/15], Iter [180,430] Loss:0.6973, average_loss: 0.6843
# Epoch [10/15], Iter [190,430] Loss:0.4585, average_loss: 0.6844
# Epoch [10/15], Iter [200,430] Loss:0.5067, average_loss: 0.6851
# Epoch [10/15], Iter [210,430] Loss:0.4419, average_loss: 0.6767
# Epoch [10/15], Iter [220,430] Loss:0.4315, average_loss: 0.6766
# Epoch [10/15], Iter [230,430] Loss:0.9020, average_loss: 0.6753
# Epoch [10/15], Iter [240,430] Loss:0.3349, average_loss: 0.6733
# Epoch [10/15], Iter [250,430] Loss:0.3277, average_loss: 0.6747
# Epoch [10/15], Iter [260,430] Loss:0.5569, average_loss: 0.6728
# Epoch [10/15], Iter [270,430] Loss:0.6537, average_loss: 0.6721
# Epoch [10/15], Iter [280,430] Loss:0.8527, average_loss: 0.6740
# Epoch [10/15], Iter [290,430] Loss:0.6307, average_loss: 0.6714
# Epoch [10/15], Iter [300,430] Loss:1.1203, average_loss: 0.6681
# Epoch [10/15], Iter [310,430] Loss:0.5053, average_loss: 0.6703
# Epoch [10/15], Iter [320,430] Loss:0.5811, average_loss: 0.6692
# Epoch [10/15], Iter [330,430] Loss:1.2581, average_loss: 0.6762
# Epoch [10/15], Iter [340,430] Loss:0.8445, average_loss: 0.6764
# Epoch [10/15], Iter [350,430] Loss:0.9023, average_loss: 0.6749
# Epoch [10/15], Iter [360,430] Loss:0.3995, average_loss: 0.6741
# Epoch [10/15], Iter [370,430] Loss:0.3049, average_loss: 0.6706
# Epoch [10/15], Iter [380,430] Loss:0.5469, average_loss: 0.6705
# Epoch [10/15], Iter [390,430] Loss:0.5873, average_loss: 0.6688
# Epoch [10/15], Iter [400,430] Loss:0.4654, average_loss: 0.6722
# Epoch [10/15], Iter [410,430] Loss:0.9646, average_loss: 0.6734
# Epoch [10/15], Iter [420,430] Loss:0.7888, average_loss: 0.6740
# Epoch [10/15], Iter [430,430] Loss:1.1255, average_loss: 0.6740
# Epoch [11/15], Iter [10,430] Loss:0.5784, average_loss: 0.4984
# Epoch [11/15], Iter [20,430] Loss:0.4189, average_loss: 0.5804
# Epoch [11/15], Iter [30,430] Loss:0.4515, average_loss: 0.6035
# Epoch [11/15], Iter [40,430] Loss:0.5636, average_loss: 0.6072
# Epoch [11/15], Iter [50,430] Loss:0.6714, average_loss: 0.6072
# Epoch [11/15], Iter [60,430] Loss:1.3499, average_loss: 0.6186
# Epoch [11/15], Iter [70,430] Loss:0.8426, average_loss: 0.6193
# Epoch [11/15], Iter [80,430] Loss:0.5695, average_loss: 0.6091
# Epoch [11/15], Iter [90,430] Loss:0.9120, average_loss: 0.6132
# Epoch [11/15], Iter [100,430] Loss:0.6567, average_loss: 0.6209
# Epoch [11/15], Iter [110,430] Loss:0.7799, average_loss: 0.6163
# Epoch [11/15], Iter [120,430] Loss:0.3823, average_loss: 0.6178
# Epoch [11/15], Iter [130,430] Loss:0.4677, average_loss: 0.6223
# Epoch [11/15], Iter [140,430] Loss:0.6816, average_loss: 0.6291
# Epoch [11/15], Iter [150,430] Loss:0.5786, average_loss: 0.6320
# Epoch [11/15], Iter [160,430] Loss:0.5499, average_loss: 0.6395
# Epoch [11/15], Iter [170,430] Loss:1.1542, average_loss: 0.6459
# Epoch [11/15], Iter [180,430] Loss:0.6612, average_loss: 0.6482
# Epoch [11/15], Iter [190,430] Loss:0.5282, average_loss: 0.6577
# Epoch [11/15], Iter [200,430] Loss:0.8385, average_loss: 0.6640
# Epoch [11/15], Iter [210,430] Loss:0.7957, average_loss: 0.6641
# Epoch [11/15], Iter [220,430] Loss:0.4781, average_loss: 0.6613
# Epoch [11/15], Iter [230,430] Loss:0.7355, average_loss: 0.6573
# Epoch [11/15], Iter [240,430] Loss:0.7495, average_loss: 0.6575
# Epoch [11/15], Iter [250,430] Loss:0.8788, average_loss: 0.6653
# Epoch [11/15], Iter [260,430] Loss:0.5542, average_loss: 0.6653
# Epoch [11/15], Iter [270,430] Loss:0.3906, average_loss: 0.6607
# Epoch [11/15], Iter [280,430] Loss:0.4643, average_loss: 0.6606
# Epoch [11/15], Iter [290,430] Loss:0.5255, average_loss: 0.6590
# Epoch [11/15], Iter [300,430] Loss:1.0093, average_loss: 0.6583
# Epoch [11/15], Iter [310,430] Loss:0.6287, average_loss: 0.6552
# Epoch [11/15], Iter [320,430] Loss:0.9400, average_loss: 0.6597
# Epoch [11/15], Iter [330,430] Loss:0.5364, average_loss: 0.6635
# Epoch [11/15], Iter [340,430] Loss:1.0203, average_loss: 0.6688
# Epoch [11/15], Iter [350,430] Loss:0.5111, average_loss: 0.6705
# Epoch [11/15], Iter [360,430] Loss:0.6039, average_loss: 0.6736
# Epoch [11/15], Iter [370,430] Loss:0.7939, average_loss: 0.6723
# Epoch [11/15], Iter [380,430] Loss:0.2281, average_loss: 0.6736
# Epoch [11/15], Iter [390,430] Loss:0.8536, average_loss: 0.6755
# Epoch [11/15], Iter [400,430] Loss:0.3137, average_loss: 0.6735
# Epoch [11/15], Iter [410,430] Loss:0.4663, average_loss: 0.6722
# Epoch [11/15], Iter [420,430] Loss:0.7695, average_loss: 0.6744
# Epoch [11/15], Iter [430,430] Loss:0.8630, average_loss: 0.6746
# Epoch [12/15], Iter [10,430] Loss:0.8112, average_loss: 0.5814
# Epoch [12/15], Iter [20,430] Loss:0.4494, average_loss: 0.6324
# Epoch [12/15], Iter [30,430] Loss:1.3427, average_loss: 0.6862
# Epoch [12/15], Iter [40,430] Loss:1.0340, average_loss: 0.6995
# Epoch [12/15], Iter [50,430] Loss:0.5278, average_loss: 0.6949
# Epoch [12/15], Iter [60,430] Loss:0.5722, average_loss: 0.6837
# Epoch [12/15], Iter [70,430] Loss:0.3133, average_loss: 0.6802
# Epoch [12/15], Iter [80,430] Loss:0.3224, average_loss: 0.6848
# Epoch [12/15], Iter [90,430] Loss:0.5588, average_loss: 0.6869
# Epoch [12/15], Iter [100,430] Loss:0.7875, average_loss: 0.6918
# Epoch [12/15], Iter [110,430] Loss:0.4123, average_loss: 0.6875
# Epoch [12/15], Iter [120,430] Loss:1.0429, average_loss: 0.6962
# Epoch [12/15], Iter [130,430] Loss:0.9585, average_loss: 0.6926
# Epoch [12/15], Iter [140,430] Loss:0.3935, average_loss: 0.6917
# Epoch [12/15], Iter [150,430] Loss:0.7997, average_loss: 0.6906
# Epoch [12/15], Iter [160,430] Loss:0.7335, average_loss: 0.6888
# Epoch [12/15], Iter [170,430] Loss:1.4501, average_loss: 0.6910
# Epoch [12/15], Iter [180,430] Loss:0.3357, average_loss: 0.6795
# Epoch [12/15], Iter [190,430] Loss:0.9868, average_loss: 0.6771
# Epoch [12/15], Iter [200,430] Loss:0.9870, average_loss: 0.6755
# Epoch [12/15], Iter [210,430] Loss:1.0161, average_loss: 0.6813
# Epoch [12/15], Iter [220,430] Loss:0.7448, average_loss: 0.6806
# Epoch [12/15], Iter [230,430] Loss:0.6099, average_loss: 0.6804
# Epoch [12/15], Iter [240,430] Loss:0.9255, average_loss: 0.6854
# Epoch [12/15], Iter [250,430] Loss:0.3691, average_loss: 0.6872
# Epoch [12/15], Iter [260,430] Loss:0.6421, average_loss: 0.6872
# Epoch [12/15], Iter [270,430] Loss:0.7175, average_loss: 0.6834
# Epoch [12/15], Iter [280,430] Loss:0.7281, average_loss: 0.6779
# Epoch [12/15], Iter [290,430] Loss:0.8522, average_loss: 0.6826
# Epoch [12/15], Iter [300,430] Loss:0.6902, average_loss: 0.6816
# Epoch [12/15], Iter [310,430] Loss:0.3569, average_loss: 0.6791
# Epoch [12/15], Iter [320,430] Loss:1.0505, average_loss: 0.6770
# Epoch [12/15], Iter [330,430] Loss:0.8959, average_loss: 0.6783
# Epoch [12/15], Iter [340,430] Loss:0.5231, average_loss: 0.6786
# Epoch [12/15], Iter [350,430] Loss:0.4552, average_loss: 0.6767
# Epoch [12/15], Iter [360,430] Loss:0.7746, average_loss: 0.6778
# Epoch [12/15], Iter [370,430] Loss:0.6636, average_loss: 0.6821
# Epoch [12/15], Iter [380,430] Loss:0.4927, average_loss: 0.6787
# Epoch [12/15], Iter [390,430] Loss:0.7197, average_loss: 0.6779
# Epoch [12/15], Iter [400,430] Loss:0.5127, average_loss: 0.6794
# Epoch [12/15], Iter [410,430] Loss:0.6327, average_loss: 0.6796
# Epoch [12/15], Iter [420,430] Loss:0.4125, average_loss: 0.6778
# Epoch [12/15], Iter [430,430] Loss:0.3814, average_loss: 0.6797
# Epoch [13/15], Iter [10,430] Loss:0.7821, average_loss: 0.6826
# Epoch [13/15], Iter [20,430] Loss:0.4630, average_loss: 0.6264
# Epoch [13/15], Iter [30,430] Loss:0.8361, average_loss: 0.6566
# Epoch [13/15], Iter [40,430] Loss:0.6206, average_loss: 0.6667
# Epoch [13/15], Iter [50,430] Loss:0.5340, average_loss: 0.6444
# Epoch [13/15], Iter [60,430] Loss:0.6044, average_loss: 0.6609
# Epoch [13/15], Iter [70,430] Loss:0.4192, average_loss: 0.6614
# Epoch [13/15], Iter [80,430] Loss:1.2158, average_loss: 0.6656
# Epoch [13/15], Iter [90,430] Loss:0.8634, average_loss: 0.6532
# Epoch [13/15], Iter [100,430] Loss:0.4711, average_loss: 0.6466
# Epoch [13/15], Iter [110,430] Loss:0.5013, average_loss: 0.6402
# Epoch [13/15], Iter [120,430] Loss:0.8170, average_loss: 0.6334
# Epoch [13/15], Iter [130,430] Loss:0.8865, average_loss: 0.6355
# Epoch [13/15], Iter [140,430] Loss:0.7342, average_loss: 0.6468
# Epoch [13/15], Iter [150,430] Loss:0.4354, average_loss: 0.6371
# Epoch [13/15], Iter [160,430] Loss:0.7532, average_loss: 0.6370
# Epoch [13/15], Iter [170,430] Loss:0.6799, average_loss: 0.6385
# Epoch [13/15], Iter [180,430] Loss:0.3605, average_loss: 0.6424
# Epoch [13/15], Iter [190,430] Loss:0.7463, average_loss: 0.6450
# Epoch [13/15], Iter [200,430] Loss:0.4205, average_loss: 0.6478
# Epoch [13/15], Iter [210,430] Loss:0.6677, average_loss: 0.6520
# Epoch [13/15], Iter [220,430] Loss:0.4284, average_loss: 0.6468
# Epoch [13/15], Iter [230,430] Loss:0.6428, average_loss: 0.6440
# Epoch [13/15], Iter [240,430] Loss:0.5830, average_loss: 0.6422
# Epoch [13/15], Iter [250,430] Loss:0.6229, average_loss: 0.6399
# Epoch [13/15], Iter [260,430] Loss:0.9043, average_loss: 0.6382
# Epoch [13/15], Iter [270,430] Loss:0.9794, average_loss: 0.6422
# Epoch [13/15], Iter [280,430] Loss:0.6519, average_loss: 0.6429
# Epoch [13/15], Iter [290,430] Loss:0.5841, average_loss: 0.6417
# Epoch [13/15], Iter [300,430] Loss:0.9278, average_loss: 0.6442
# Epoch [13/15], Iter [310,430] Loss:0.5014, average_loss: 0.6439
# Epoch [13/15], Iter [320,430] Loss:0.3205, average_loss: 0.6453
# Epoch [13/15], Iter [330,430] Loss:0.9420, average_loss: 0.6465
# Epoch [13/15], Iter [340,430] Loss:0.3662, average_loss: 0.6492
# Epoch [13/15], Iter [350,430] Loss:1.0290, average_loss: 0.6522
# Epoch [13/15], Iter [360,430] Loss:0.4002, average_loss: 0.6493
# Epoch [13/15], Iter [370,430] Loss:0.5251, average_loss: 0.6492
# Epoch [13/15], Iter [380,430] Loss:0.6863, average_loss: 0.6508
# Epoch [13/15], Iter [390,430] Loss:0.8761, average_loss: 0.6501
# Epoch [13/15], Iter [400,430] Loss:0.7277, average_loss: 0.6487
# Epoch [13/15], Iter [410,430] Loss:0.7299, average_loss: 0.6487
# Epoch [13/15], Iter [420,430] Loss:0.7261, average_loss: 0.6486
# Epoch [13/15], Iter [430,430] Loss:0.3701, average_loss: 0.6476
# Epoch [14/15], Iter [10,430] Loss:1.1040, average_loss: 0.7738
# Epoch [14/15], Iter [20,430] Loss:0.3738, average_loss: 0.6527
# Epoch [14/15], Iter [30,430] Loss:0.5783, average_loss: 0.6534
# Epoch [14/15], Iter [40,430] Loss:0.6999, average_loss: 0.6460
# Epoch [14/15], Iter [50,430] Loss:0.9942, average_loss: 0.6326
# Epoch [14/15], Iter [60,430] Loss:0.5910, average_loss: 0.6282
# Epoch [14/15], Iter [70,430] Loss:0.4263, average_loss: 0.6428
# Epoch [14/15], Iter [80,430] Loss:0.4664, average_loss: 0.6326
# Epoch [14/15], Iter [90,430] Loss:0.4693, average_loss: 0.6228
# Epoch [14/15], Iter [100,430] Loss:0.3639, average_loss: 0.6252
# Epoch [14/15], Iter [110,430] Loss:0.8266, average_loss: 0.6205
# Epoch [14/15], Iter [120,430] Loss:0.5538, average_loss: 0.6342
# Epoch [14/15], Iter [130,430] Loss:0.8201, average_loss: 0.6402
# Epoch [14/15], Iter [140,430] Loss:0.4532, average_loss: 0.6470
# Epoch [14/15], Iter [150,430] Loss:0.5925, average_loss: 0.6414
# Epoch [14/15], Iter [160,430] Loss:0.2830, average_loss: 0.6372
# Epoch [14/15], Iter [170,430] Loss:0.7425, average_loss: 0.6305
# Epoch [14/15], Iter [180,430] Loss:0.8437, average_loss: 0.6360
# Epoch [14/15], Iter [190,430] Loss:0.7021, average_loss: 0.6381
# Epoch [14/15], Iter [200,430] Loss:0.4401, average_loss: 0.6404
# Epoch [14/15], Iter [210,430] Loss:0.5875, average_loss: 0.6419
# Epoch [14/15], Iter [220,430] Loss:0.7227, average_loss: 0.6453
# Epoch [14/15], Iter [230,430] Loss:0.7448, average_loss: 0.6391
# Epoch [14/15], Iter [240,430] Loss:0.6274, average_loss: 0.6387
# Epoch [14/15], Iter [250,430] Loss:0.4887, average_loss: 0.6388
# Epoch [14/15], Iter [260,430] Loss:0.8621, average_loss: 0.6458
# Epoch [14/15], Iter [270,430] Loss:0.5744, average_loss: 0.6452
# Epoch [14/15], Iter [280,430] Loss:0.6985, average_loss: 0.6474
# Epoch [14/15], Iter [290,430] Loss:0.7239, average_loss: 0.6453
# Epoch [14/15], Iter [300,430] Loss:0.5348, average_loss: 0.6477
# Epoch [14/15], Iter [310,430] Loss:0.7274, average_loss: 0.6491
# Epoch [14/15], Iter [320,430] Loss:0.3822, average_loss: 0.6488
# Epoch [14/15], Iter [330,430] Loss:0.3223, average_loss: 0.6462
# Epoch [14/15], Iter [340,430] Loss:1.5268, average_loss: 0.6466
# Epoch [14/15], Iter [350,430] Loss:0.3428, average_loss: 0.6505
# Epoch [14/15], Iter [360,430] Loss:0.7575, average_loss: 0.6510
# Epoch [14/15], Iter [370,430] Loss:0.6015, average_loss: 0.6505
# Epoch [14/15], Iter [380,430] Loss:0.3127, average_loss: 0.6498
# Epoch [14/15], Iter [390,430] Loss:0.4650, average_loss: 0.6455
# Epoch [14/15], Iter [400,430] Loss:0.3490, average_loss: 0.6429
# Epoch [14/15], Iter [410,430] Loss:0.9135, average_loss: 0.6451
# Epoch [14/15], Iter [420,430] Loss:0.4796, average_loss: 0.6432
# Epoch [14/15], Iter [430,430] Loss:0.4862, average_loss: 0.6399
# Epoch [15/15], Iter [10,430] Loss:0.4061, average_loss: 0.6276
# Epoch [15/15], Iter [20,430] Loss:0.7001, average_loss: 0.6049
# Epoch [15/15], Iter [30,430] Loss:0.5185, average_loss: 0.5790
# Epoch [15/15], Iter [40,430] Loss:0.6863, average_loss: 0.5915
# Epoch [15/15], Iter [50,430] Loss:0.6478, average_loss: 0.6053
# Epoch [15/15], Iter [60,430] Loss:0.7748, average_loss: 0.6047
# Epoch [15/15], Iter [70,430] Loss:0.6809, average_loss: 0.5930
# Epoch [15/15], Iter [80,430] Loss:0.7177, average_loss: 0.5891
# Epoch [15/15], Iter [90,430] Loss:1.0771, average_loss: 0.5981
# Epoch [15/15], Iter [100,430] Loss:0.4107, average_loss: 0.6040
# Epoch [15/15], Iter [110,430] Loss:0.2899, average_loss: 0.6045
# Epoch [15/15], Iter [120,430] Loss:0.4839, average_loss: 0.5978
# Epoch [15/15], Iter [130,430] Loss:0.3057, average_loss: 0.5958
# Epoch [15/15], Iter [140,430] Loss:0.8902, average_loss: 0.6061
# Epoch [15/15], Iter [150,430] Loss:0.5507, average_loss: 0.6135
# Epoch [15/15], Iter [160,430] Loss:1.0406, average_loss: 0.6192
# Epoch [15/15], Iter [170,430] Loss:0.6197, average_loss: 0.6234
# Epoch [15/15], Iter [180,430] Loss:0.3155, average_loss: 0.6235
# Epoch [15/15], Iter [190,430] Loss:0.5117, average_loss: 0.6192
# Epoch [15/15], Iter [200,430] Loss:0.5856, average_loss: 0.6162
# Epoch [15/15], Iter [210,430] Loss:0.8075, average_loss: 0.6180
# Epoch [15/15], Iter [220,430] Loss:0.8193, average_loss: 0.6263
# Epoch [15/15], Iter [230,430] Loss:0.6382, average_loss: 0.6311
# Epoch [15/15], Iter [240,430] Loss:0.4064, average_loss: 0.6323
# Epoch [15/15], Iter [250,430] Loss:0.4309, average_loss: 0.6323
# Epoch [15/15], Iter [260,430] Loss:0.5509, average_loss: 0.6331
# Epoch [15/15], Iter [270,430] Loss:0.5361, average_loss: 0.6350
# Epoch [15/15], Iter [280,430] Loss:0.6176, average_loss: 0.6392
# Epoch [15/15], Iter [290,430] Loss:0.9332, average_loss: 0.6474
# Epoch [15/15], Iter [300,430] Loss:0.8014, average_loss: 0.6496
# Epoch [15/15], Iter [310,430] Loss:0.6555, average_loss: 0.6483
# Epoch [15/15], Iter [320,430] Loss:0.7304, average_loss: 0.6478
# Epoch [15/15], Iter [330,430] Loss:0.5886, average_loss: 0.6460
# Epoch [15/15], Iter [340,430] Loss:0.7232, average_loss: 0.6486
# Epoch [15/15], Iter [350,430] Loss:0.7314, average_loss: 0.6464
# Epoch [15/15], Iter [360,430] Loss:0.6037, average_loss: 0.6474
# Epoch [15/15], Iter [370,430] Loss:0.5207, average_loss: 0.6459
# Epoch [15/15], Iter [380,430] Loss:1.0402, average_loss: 0.6458
# Epoch [15/15], Iter [390,430] Loss:0.5256, average_loss: 0.6453
# Epoch [15/15], Iter [400,430] Loss:0.8024, average_loss: 0.6474
# Epoch [15/15], Iter [410,430] Loss:0.4649, average_loss: 0.6494
# Epoch [15/15], Iter [420,430] Loss:0.7213, average_loss: 0.6487
# Epoch [15/15], Iter [430,430] Loss:0.8151, average_loss: 0.6534

# %% [markdown]
# ### Step 5. Inference

# %% [markdown]
# ### Step 5-1. Inference (Visualizing)
# - The below code is for visualizing your results.
# - Check out!

# %%
## Visualizing the bouding box image
from codes.lab8.util import *

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')

Color = [[0, 0, 0],
                    [128, 0, 0],
                    [0, 128, 0],
                    [128, 128, 0],
                    [0, 0, 128],
                    [128, 0, 128]]

def visualize(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()
    
    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0.1)
    
    for i, box in enumerate(boxes):
        
        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        result.append([(x1, y1), (x2, y2), SMALL_VOC_CLASSES[cls_index], prob])
        
    img = np.zeros((h, w, 3), np.uint8)
    img = img + image[:,:,::-1]
        
    for left_up,right_bottom,class_name,prob in result:
        color = Color[SMALL_VOC_CLASSES.index(class_name)]
        cv2.rectangle(img, left_up, right_bottom, color, 2)
        label = class_name+str(round(prob,2))
        text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
        p1 = (left_up[0], left_up[1]- text_size[1])
        cv2.rectangle(img, (p1[0] - 2//2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]), color, -1)
        cv2.putText(img, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255,255,255), 1, 8)
    
    plt.imshow(img)
    
model.eval()
visualize(model, 'codes_util/lab8/Generate_dataset/images/003033.jpg')

# %% [markdown]
# ### Step 6-2. Inference (mAP)
# - The below code is for checkout your network performance,
# - By using this code, your network prediction is saved in Generate_dataset directory
# - Then, %run ./codes_util/lab8/Generate_dataset/main.py
# - After a few seconds, the mAP is printed.
# - **Note that if your code is correct, the mAP will be over 70.**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')

def write(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()
    
    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0)
    
    txt_file = open('codes_util/lab8/Generate_dataset/predicted/'+os.path.basename(path)[:-4]+'.txt', 'w')
    
    for i, box in enumerate(boxes):
        
        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        txt_file.write(str(SMALL_VOC_CLASSES[cls_index])+' '+'%.6f'%(prob)+' '+str(x1)+' '+str(y1)+' '+str(x2)+' '+str(y2))
        txt_file.write('\n')
    txt_file.close()
    
import glob

model.eval()
img_names = glob.glob('codes_util/lab8/Generate_dataset/images/*')

for i, file_name in enumerate(img_names):
    write(model, file_name)
    if i % 500 == 0:
        print(i)
# Out:
# 0
# 500
# 1000

# %%
# %run ./codes_util/lab8/Generate_dataset/main.py
# Out:
# 67.83% = aeroplane AP
# 68.00% = bicycle AP
# 66.17% = bus AP
# 68.21% = car AP
# 72.44% = cat AP
# 78.88% = dog AP
# mAP = 70.25%

# %% [markdown]
# ### *References*
# [1] https://www.pyimagesearch.com/2018/05/14/a-gentle-guide-to-deep-learning-object-detection/
#
# [2] https://github.com/Cartucho/mAP

# %% [markdown]
# Result report by written Cha, Hyunsoo
# =
#
# Analyze Algorithm
# ==
# In this experiment, I had a lot of worries about how to process and put the image. According to the given code, the minimum value of x and the maximum value of y are extracted from the text file to process the image for the dataset, and the class value is also extracted from the text file. The position of the box in the image is stored as a tensor through the maximum minimum value of x, y.
#
# The YOLO model was written reflecting the modifications made from the content mentioned in the paper. The singularity is that I set the negative slope of the LeakyReLU to 0.01 for postnet. This allowed me to obtain a loss function that converges without giving off.
#
# Loss function refers to code for the function "contain_obj_error" and "not_contain_obj_error". Principles of implementation are quite similar. Rearrange the output vector to be as large as 30 via view(-1, 30). For the Compute_prob_error function, it was modified to allow computation by machining it to [:, 10:] before being inserted into the MSE Loss function. For the function not_contain_obj_error, I created a mask similar to the function container_obj_error and put it into the Loss function.
#
# For the Container_obj_error function, I estimated the coordinates by adding or subtracting 14 divided by 2 to estimate the bounding box coordinate. When determining whether an object was included in the box, the resulting value was re-processed as view (-1, 5).
#
# Compare and Discuss the Results
# ==
# Let me discuss the consequences. Qualitatively, the supercar photo showed that the supercar was located in the bounding box. For mAP, 70.25 per cent. More specifically, aeroplane 67.83%, bicycles 68, buses 66.17%, cars 68.21%, cats 72.44% and dogs 78.88%. The experiment was successful but somewhat difficult.
